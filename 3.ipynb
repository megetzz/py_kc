# %% [markdown]
# ###  python数据可视化工具 网址  http://www.pythontutor.com/

# %% [markdown]
# python 如何操作数据库

# %% [markdown]
# 爬虫

# %% [markdown]
# ## 数据库

# %% [markdown]
# 我们平时说的数据库,是数据库管理系统

# %% [markdown]
# ### mysql数据库

# %% [markdown]
# MariaDB  MariaDB 目前完全兼容MySQL,包括API和命令行,使之能轻松称为 MySQL的代替品

# %% [markdown]
# ### 关系型数据库

# %% [markdown]
# 非关系型数据库:比较流行的有 Mongodb,redis

# %%
dict = {'a':100,'b':300}

# %% [markdown]
# json   接口

# %%
import json
with open(r'C:\Users\zz\Desktop\data.json') as f:
#     f.readlines()
    json.load(f)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-25-7833d3cfadb6> in <module>
#       2 with open(r'C:\Users\zz\Desktop\data.json') as f:
#       3 #     f.readlines()
# ----> 4     json.load(f)
#
# D:\python_3.8\lib\json\__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#
# D:\python_3.8\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# ...

# %%
import json

data_1 = '{"a":1,"b":2,"c":0}'
data_2 = '{"a":1,"b":2,"c":7}'

j_data = json.loads(data_2)
type(j_data)
# Out:
# dict

# %% [markdown]
# mysql数据库操作 `

# %% [markdown]
# #### 命令行操作

# %%
#登录
mysql -u root -p;
#查看数据库
show databases;
#选择数据库
use database_name;
#查看数据库的表
show tables;
#查看表结构
desc tables;
#查看表数据
select * from table_name;
#查看表数据并限制数量 
select * from table_name limit 10;

# %% [markdown]
# create database Examination_copy;
# drop database Examonation_copy;
# 指定字符集和校对集,创建数据库
# create database Examination_copy default charset: urf8mb4 collate utf8mb4_general_ci;

# %%
插入数据 
insert into '表'(字段) values(值)

修改数据 
update '表' set  字段 = '值' where '字段' = '值

删除
delete from '表' where '字段' = '值'

# %% [markdown]
# # 使用python操作数据库

# %%
import MySQLdb

# %%
# 连接数据库
DATABASE = {
    'host':'127.0.0.1',
    'database':'examination_copy',
    'user':'root',
    'password':'258000',
    'charset':'utf8mb4'
}

db = MySQLdb.connect(**DATABASE)

# %% [markdown]
# ### 游标

# %%
cursor = db.cursor()

# %%
sql = 'show tables'
cursor.execute(sql)
results = cursor.fetchall()
for row in results:
    print(row)

# %%
 pip install bs4
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Using cached https://pypi.tuna.tsinghua.edu.cn/packages/10/ed/7e8b97591f6f456174139ec089c769f89a94a1a4025fe967691de971f314/bs4-0.0.1.tar.gz
# ...
# Note: you may need to restart the kernel to use updated packages.Collecting soupsieve>1.2
# ...
#
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-cp38-none-any.whl size=1280 sha256=8faeae55f33f7f0e51b6f5585c0942efebfb8761003210631a97f9ddc170096a
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
#   Stored in directory: C:\Users\zz\AppData\Local\pip\Cache\wheels\e4\59\6e\68fcba6d232218f798c3482f9fa203498032617f00bc6840db
# Successfully built bs4
# ...

# %% [markdown]
# 爬虫

# %% [markdown]
# requests
# beautifulSoup

# %%
import requests


from bs4 import BeautifulSoup

# %%
url = 'https://bj.lianjia.com/zufang/'
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible">
# <meta content="no-transform" http-equiv="Cache-Control"/>
# <meta content="no-siteapp" http-equiv="Cache-Control"/>
# <meta content="zh-CN" http-equiv="Content-language"/>
# <meta content="telephone=no" name="format-detection"/>
# <meta content="pc" name="applicable-device"/>
# <meta content="no-transform " http-equiv="Cache-Control">
# <!-- seo关键字相关信息 -->
# <meta content="贝壳北京租房网,提供真实的北京租房信息、出租房源信息、租房价格,包括北京整租、合租、公寓出租等信息,以及北京房屋出租个人信息、经纪人信息、品牌公寓信息等.找租房房源,就来北京贝壳租房!" name="description"/>
# <meta content="北京租房信息,北京出租房网,北京房屋出租价格" name="keywords"/>
# <title>北京租房信息_北京出租房源|房屋出租价格【北京贝壳租房】</title>
# <!--地址信息-->
# <meta content="province=北京;city=北京" name="location"/>
# <!-- 网站ico图标 -->
# <link href="https://s1.ljcdn.com/matrix_pc/dist/pc/src/resource/lianjia/favicon.ico?_v=20200616155219451" rel="icon" type="image/x-icon"/>
# ...

# %%
links_div = soup.findall('div',class_='content__list--item--aside')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-99ec41d77204> in <module>
# ----> 1 links_div = soup.findall('div',class_='content__list--item--aside')
#
# TypeError: 'NoneType' object is not callable

# %%
links_div[1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-91-84fe66d0a123> in <module>
# ----> 1 links_div[1]
#
# NameError: name 'links_div' is not defined
