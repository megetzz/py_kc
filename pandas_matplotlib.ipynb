# %%
import numpy as np  
import matplotlib.pyplot as pt  
x = np.arange(0 , 360)  
y = np.sin( x * np.pi / 180.0)  
pt.plot(x,y)  
pt.xlim(0,360)  
pt.ylim(-1.2,1.2)  
pt.title("SIN function")  
pt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# 必不可少i
# %matplotlib inline

# %%
x = np.linspace(0,10,100)
y = np.sin(x)
 
plt.plot(x,y)
plt.plot(x,np.cos(x))

# %%
plt.plot(x,y,'-*')

# %%
fig = plt.figure()
plt.plot(x,y,'--')

# %%
# 保存
fig.savefig(r'C:\Users\zz\Desktop\桌面整理\first_figure.png')

# %%
# 虚线样式
plt.subplot(2,1,1)
plt.title('sin')
plt.plot(x,np.sin(x),'--')

plt.subplot(2,1,2)
plt.title('cos')
plt.plot(x,np.cos(x))

# %%
# 点状样式
x = np.linspace(0,10,30)
plt.plot(x,np.sin(x),'o')

# %%
# 点状样式
x = np.linspace(0,10,30)
plt.plot(x,np.sin(x),'o',color= '#ff00ff')

# %% [markdown]
# # 标题title 提示label 解决办法
# * from matplotlib import  pyplot
# * pyplot.rcParams['font.sans-serif']=['SimHei']
# * plt.legend()

# %%
import numpy as np  
import matplotlib.pyplot as pt 
from matplotlib import  pyplot

x = np.linspace(0,10,25)
y = np.sin(x)
pyplot.rcParams['font.sans-serif']=['SimHei']
plt.title('三角函数')
plt.plot(x,y,label = 'sin(x)')
plt.plot(x,np.cos(x),'o',label = 'cos(x)')
plt.plot(x,np.tan(x),'--',label = 'tan(x)')
# legend 控制label的显示效果, loc 控制label的显示位置
plt.legend()
plt.show()

# %%
plt.legend

# %%
 # plot函数，可定制的参数非常多   使用时查看
x = np.linspace(0, 10, 20)
y = np.sin(x)
plt.plot(x, y, '-d', 
         color='black',
         markersize=10, 
         linewidth=1, 
         markeredgecolor='red',
         markeredgewidth=1)

# %%
# ylim xlim 限定范围
plt.plot(x,y,'-d',color='red',markersize=16,linewidth=2,markeredgecolor='blue',markeredgewidth=1)
plt.ylim(-0.5,1.2)
plt.xlim(2,8)
# Out:
# (2, 8)

# %%
# 散点图?
plt.scatter(x,y,s=10,c='red')

# %%
# plt.style.use('seaborn-whitegrid')

x = np.random.randn(100)
y = np.random.randn(100)
colors = np.random.rand(100)
# sizes = 1000 * np.random.rand(100)
sizes =1000 *  np.random.rand(100)
# plt.scatter(x,y,c = colors,s = sizes,alpha=0.4)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3)
plt.colorbar()

# %% [markdown]
# # pandas本身自带绘图`

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 线性图

# %%
df = pd.DataFrame(np.random.rand(100,4).cumsum(0),columns=['A','B','C','D'])
# df = pd.DataFrame(np.random.rand(100,4).cumsum(0), columns=['A', 'B', 'C', 'D'])
df.plot()

# %% [markdown]
# # 柱状图

# %%
df.plot.bar()

# %%
df = pd.DataFrame(np.random.randint(10,50,(3,4)),columns=['A','B','C','D'],index=['one','two','three'])
df.plot.bar()

# %%
df.A.plot.bar()

# %%
# 等价于上述绘图
df.plot(kind='bar',stacked = True) # 等加

# %% [markdown]
# ## 直方图

# %%
df = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E5A7A71860>,
# ...
#       dtype=object)

# %%
df = pd.DataFrame(np.random.randn(100,4),columns=['A','B','C','D'])
df.hist(column='C',figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E5A7BBCEF0>]],
#       dtype=object)

# %% [markdown]
# # 密度图

# %%
df.plot.kde()

# %%
df.plot(kind='kde')

# %% [markdown]
# # 3D

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator,FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection = '3d')

# 设置数据
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# 绘制表面
surf = ax.plot_surface(X,Y,Z,cmap = cm.coolwarm,linewidth = 0,antialiased = False)

# 绘制Z轴

ax.set_zlim(-1.01,1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

#添加一个将值映射到颜色的颜色条。
fig.colorbar(surf,shrink = 0.5, aspect = 5)

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
